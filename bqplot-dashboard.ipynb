# %%
import pandas as pd
import bqplot
import numpy as np
import traitlets
import ipywidgets
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#reading dataset directly from web and putting it into a variable
building_data = pd.read_csv('https://uiuc-ischool-dataviz.github.io/is445_AOUAOG_fall2021/week02/data/building_inventory.csv')

# %%
building_data
# Out:
#                            Agency Name  \
# 0      Department of Natural Resources
# 1      Department of Natural Resources
# 2      Department of Natural Resources
# 3      Department of Natural Resources
# 4      Department of Natural Resources
# ...                                ...
# 8857      Department of Transportation
# 8858      Department of Transportation
# 8859      Department of Transportation
# 8860  Illinois Community College Board
# 8861    Department of Military Affairs
#
#                                           Location Name  \
# 0       Anderson Lake Conservation Area - Fulton County
# 1       Anderson Lake Conservation Area - Fulton County
# 2       Anderson Lake Conservation Area - Fulton County
# 3       Anderson Lake Conservation Area - Fulton County
# 4       Anderson Lake Conservation Area - Fulton County
# ...                                                 ...
# 8857  Belvidere Maintenance Storage Facility - Boone...
# ...

# %%
building_data = pd.read_csv("https://uiuc-ischool-dataviz.github.io/is445_AOUAOG_fall2021/week02/data/building_inventory.csv",
           na_values = {'Square Footage': 0,
                       'Year Acquired': 0,
                       'Year Constructed': 0}) 
# replacing 0's with NaN or not-a-number
#creating a clean dataset from Buildings dataset

# %%
total_by_region = pd.pivot_table(building_data, index = "Agency Name", columns = "County", values = "Square Footage", aggfunc='mean')

# %%
mySelectedLabel = ipywidgets.Label() # start with our label

# %%
hist = bqplot.Hist(sample=building_data[i,j,:], 
                  scales={'sample':x_sch, 'count':y_sch}, bins=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18092/3189366727.py in <module>
# ----> 1 hist = bqplot.Hist(sample=building_data[i,j,:],
#       2                   scales={'sample':x_sch, 'count':y_sch}, bins=5)
#
# NameError: name 'i' is not defined

# %%
# 1. Data -- same as above
# 2. Scales
col_sc = bqplot.ColorScale(scheme = 'Reds') # like x/y scale, but in "color space"
x_sc = bqplot.OrdinalScale() # ordered, categorical data, because our bins are more like categorical bins
y_sc = bqplot.OrdinalScale()


# 3. Marks
heat_map = bqplot.GridHeatMap(color=total_by_region, scales={'color':col_sc, 'row':y_sc, 'column':x_sc},
                             interactions={'click':'select'},
                             anchor_style={'fill':'blue'})
# note: we can pass arrays/lists of names for each categorical column, here we are just
#. passing the scales

# 4. Axis 
c_ax = bqplot.ColorAxis(scale=col_sc, orientation='vertical', side='right')
x_ax = bqplot.Axis(scale=x_sc)
y_ax = bqplot.Axis(scale=y_sc, orientation='vertical')

mySelectedLabel = ipywidgets.Label()
mySelectedLabel.value = 'Mean selected point here'
# 5. Interactions, skipping as well
def get_data_value(change):
    i,j = change['owner'].selected[0]
    mask = (building_data['Agency Name'] == total_by_region.index[i]) & \
            (building_data['County'] == total_by_region.columns.levels[1][j])
    # grab buildings subset dataframe
    buildings_subset = building_data[mask]
    # grab years and sqft from pandas
    grouped = building_data.groupby("Year Acquired")["Square Footage"].sum()
    years = grouped.index
    sqft = grouped.values
    bar.x = years
    bar.y = sqft
    
# 6. Figure object
fig = bqplot.Figure(marks=[heat_map], axes=[c_ax, x_ax, y_ax])
fig
# Out:
# Figure(axes=[ColorAxis(orientation='vertical', scale=ColorScale(scheme='Reds'), side='right'), Axis(scale=Ordi…

# %%
# (1) scales: x/y, linear
x_sch = bqplot.LinearScale() # range of z-axis data
y_sch = bqplot.LinearScale() # frequency of z-axis data in bins

# (2) axis: x/y
x_axh = bqplot.Axis(scale = x_sch, label = 'Value of 3rd axis')
y_axh = bqplot.Axis(scale = y_sch, 
                    orientation = 'vertical', 
                    label='Frequency')

# (3) Marks: histogram - start with just 0,0 in i/j -- can do other place holders
hist = bqplot.Hist(sample = building_data[0,0,:],
                   normalized = False, # normalized=False means we get counts in each bin
                   scales = {'sample': x_sch, 'count': y_sch}, # sample is data values, count is frequency
                   bins = 5) # number of bins

# (4) NO LINKING ON HISTOGRAM SIDE

# (5) Paint histogram canvas, don't display yet
fig_hist = bqplot.Figure(marks = [hist], axes = [x_axh, y_axh])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24592/129300825.py in <module>
#      10
#      11 # (3) Marks: histogram - start with just 0,0 in i/j -- can do other place holders
# ---> 12 hist = bqplot.Hist(sample = building_data[0,0,:],
#      13                    normalized = False, # normalized=False means we get counts in each bin
#      14                    scales = {'sample': x_sch, 'count': y_sch}, # sample is data values, count is frequency
#
# ~\anaconda3\envs\DataViz\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ...
